# %% [markdown]
# # 📊 Proyecto: Análisis Comercial Inmobiliario
#
# El sector inmobiliario necesita evaluar su **desempeño comercial** para comprender su crecimiento, rentabilidad y comportamiento de clientes.
#
# Se solicita construir un **dashboard ejecutivo** que permita analizar ventas, clientes y propiedades para apoyar decisiones estratégicas basadas en datos.

# %% [markdown]
# # 📂 Descripción de los Datasets
#
# 🔹 **hecho_ventas_propiedades**
# Tabla de hechos con las transacciones de venta (precio, cliente, propiedad, canal, fecha).
#
# 🔹 **dim_clientes**
# Información y segmentación de clientes.
#
# 🔹 **dim_propiedades**
# Características de las propiedades (tipo, tamaño, ubicación, etc).
#
# 🔹 **dim_fecha**
# Tabla calendario que deberá ser creada como parte del modelado.

# %% [markdown]
# # 🎯 Preguntas que el dashboard debe responder
#
# **Desempeño general**
#
# - ¿Cuál es el **ingreso total** generado por la empresa?
# - ¿Cuántas **propiedades se han vendido**?
# - ¿Cuál es el **precio promedio de venta**?
# - ¿Cuál es la **comisión total** generada por la empresa?
#
# **Análisis comercial**
#
# - ¿Qué **tipo de propiedad genera más ingresos**?
# - ¿Qué **segmento de clientes compra más propiedades**?
# - ¿Qué canal de venta **genera mayor ingresos**?
#
#
# **Análisis temporal**
#
# - ¿Cómo evolucionan las **ventas en el tiempo**?
# - ¿El negocio está **creciendo año contra año**?
# - ¿Cómo va el desempeño **acumulado del año actual (YTD)**?
#
# **Cohortes de clientes**
#
# - ¿Los clientes **vuelven a comprar** después de su primera compra?
# - ¿Qué **cohortes de clientes generan más compras/ingresos con el tiempo**?

# %% [markdown]
# ## 📝Resumen Ejecutivo
#
# Escribe aquí un resumen con:
#
# - hallazgos clave
# - métricas principales
# - insights accionables
# - recomendaciones estratégicas
#
# Ejemplos:
#
# **Hallazgos clave**
# - El ingreso total del periodo fue de 6,012.50 mill. generado por un volumen de 8,500 ventas totales.
# - El tipo de propiedad que genera mayor revenue es Casa, acumulando un ingreso de 2,240.54 mill. dentro de la facturación comercial.
# - La ciudad con mayor volumen de ventas e ingresos es Ciudad de México, liderando el mercado regional con un aporte de 3.24 mil M (millones).
# - El canal de venta más eficiente en términos de ingresos es Corredor, representando la fuerza principal de comercialización frente al canal Directo.
#
# **Métricas principales**
# - Ingreso Total: 6.01 mil M (6,012,502,170.00)
# - Cantidad de Ventas: 8.50 mil (8,500 transacciones)
# - Ticket Promedio: 707.35 mil (707,353.20)
# - Comisión Total: 200.63 mill. (200,634,510.00)
#
# **Insights accionables**
# - El segmento de clientes Primera vez concentra la mayor parte del ingreso del negocio, consolidándose como el perfil de comprador más crítico para la compañía.
# - Los clientes adquiridos en las cohortes de 2024 muestran un comportamiento inicial volumétrico más alto; sin embargo, las cohortes de inicios de 2023 reflejan una mayor salud transaccional en el tiempo, sosteniendo zonas de recompra estables (colores naranja/amarillo) en meses posteriores en comparación con la rápida caída hacia el rojo que sufren las de 2024.
# - Las ventas muestran una marcada tendencia al alza, reflejando un crecimiento continuo en la actividad del negocio conforme avanzan los periodos analizados.
#
# **Recomendaciones estratégicas**
# - Priorizar la comercialización de propiedades tipo Casa, apalancando el alto impacto que tienen sobre el revenue total e impulsando estrategias de marketing dirigidas específicamente a este producto estrella.
# - Fortalecer y proteger el canal de ventas Corredor, el cual presenta la mayor participación en el revenue del negocio con un 72.85% del total de los ingresos comerciales ($4,379.99 mill.).
# - Implementar estrategias de retención enfocadas en mejorar la recompra en cohortes recientes, diseñando planes de fidelización post-venta específicos para los clientes adquiridos en 2024, con el fin de mitigar su temprana caída en inactividad (zonas rojas de la matriz) y replicar la consistencia de los clientes de 2023.

# %%
# (Pega aquí tu link)
https://drive.google.com/drive/folders/11ZZE3B7phsjAxJtjZJWTFXi3OvIM3GsS?usp=sharing
